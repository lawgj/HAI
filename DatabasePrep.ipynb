# %%
import numpy as np
import pandas as pd
import sqlite3 as db
import random
from datetime import date, timedelta, datetime
from faker import Faker
import os
from itertools import product

# %% [markdown]
# ## Create A Database for Healthcare Data and A Database for Patient Data

# %%
hb = [['Capital Region', 'CPR', 20000], 
             ['Forest Heights', 'FRH', 11000], 
             ['Middlepark', 'MPK', 8000],
             ['The Dale', 'DLE', 1500]]

hb_df = pd.DataFrame(hb, columns=['Health Board', 'Health Board Code', 'Population'])

hospitals = [['University Hospital Capital','UHC123','Acute','CPR'],
             ['Downtown Hospital','DTH111','Non Acute','CPR'],
             ['Southside General','SSG001','Acute','CPR'],
             ['Fir Tree General','FTG221','Non Acute','FRH'],
             ['Oaken Ridge Infirmary','ORI010','Acute','FRH'],
             ['New Hope Hospital','NHH131','Acute','MPK'],
             ['Bright Dawn Hospital','BDH101','Acute','MPK'],
             ['The Valley Infirmary','TVI854','Acute','DLE']]

hospitals_df = pd.DataFrame(hospitals, columns=['Hospital Name', 
                                                'Hospital Code', 
                                                'Acute Status', 
                                                'Health Board Code'])

wards = [['ICU A','UHC:ICUA','UHC123'],
        ['ICU B','UHC:ICUB','UHC123'],
        ['A&E',	'UHC:AE','UHC123'],
        ['Ward 1','UHC:1','UHC123'],
        ['Ward 2','UHC:2','UHC123'],
        ['Maternity','UHC:MAT','UHC123'],
        ['Palliative','DTH:PAL','DTH111'],
        ['Ward 1','DTH:1','DTH111'],
        ['Ward 2','DTH:2','DTH111'],
        ['Paediatrics','SSG:PAE','SSG001'],
        ['Oncology','SSG:ONC','SSG001'],
        ['A&E','SSG:AE','SSG001'],
        ['Geriatrics','FTG:GER','FTG221'],
        ['Ward 1','FTG:1','FTG221'],
        ['Psychiatic','FTG:PSY','FTG221'],
        ['Internal Medicine','ORI:INTM','ORI010'],
        ['General Medicine','ORI:GENM','ORI010'],
        ['Ward 1','ORI:1','ORI010'],
        ['Ward 1','NHHL1','NHH131'],
        ['Respiratory','NHH:RES','NHH131'],
        ['ICU A','BGH:ICUA','BDH101'],
        ['ICU B','BGH:ICUB','BDH101'],
        ['Ward 1','BGH:1','BDH101'],
        ['A&E','TVI:AE','TVI854']]

wards_df = pd.DataFrame(wards, columns=['Ward Name', 
                                                'Ward Code',
                                                'Hospital Code'])

# Set seed for reproducibility
random.seed(123)

# Initialize faker
fake = Faker()

# Define the number of entries for the dataset
num_entries = 5000

# Generate fake data for each column
patient_id = [random.randint(100000, 999999) for _ in range(num_entries)]
age = [random.randint(18, 90) for _ in range(num_entries)]
sex = [random.choice(['Male', 'Female']) for _ in range(num_entries)]
unit_admission_date = [fake.date_between_dates(date(2019, 1, 1), date.today()) for _ in range(num_entries)]
unit_discharge_date = [admission + timedelta(days=random.randint(0, 30)) for admission in unit_admission_date]
specimen_date = [fake.date_between_dates(admission, discharge) if random.random() < 0.3 else fake.date_between(start_date=date(2019, 1, 1), end_date=date.today()) for admission, discharge in zip(unit_admission_date, unit_discharge_date)]
organism = [random.choice(["Staphylococcus aureus", "Escherichia coli", "Pseudomonas aeruginosa", "Enterococcus faecalis", "Klebsiella pneumoniae"]) for _ in range(num_entries)]
ward = [random.choice(wards_df['Ward Code'].unique()) for _ in range(num_entries)]

# Create the patient data dictionary
patient_data = {
    "Patient ID": patient_id,
    "Age": age,
    "Sex": sex,
    "Unit Admission Date": unit_admission_date,
    "Unit Discharge Date": unit_discharge_date,
    "Specimen Date": specimen_date,
    "Organism": organism,
    "Ward Code": ward
}
patient_data_df = pd.DataFrame.from_dict(patient_data)

con = db.connect(os.path.realpath('HealthCareData.db'))
hb_df.to_sql('hb', con, if_exists='replace')
hospitals_df.to_sql('hospitals', con, if_exists='replace')
wards_df.to_sql('wards', con, if_exists='replace')
con.close()
con = db.connect(os.path.realpath('PatientData.db'))
patient_data_df.to_sql('patients', con, if_exists='replace')
con.close()

# %% [markdown]
# ## Read in data from databases

# %%
# Connect to healthcare database
conn = db.connect('HealthCareData.db')

# Create cursor object
cursor = conn.cursor()

# Query for LEFT JOIN
sql_query = '''SELECT 
w.[Ward Name], w.[Ward Code], w.[Hospital Code],
h.[Hospital Name], h.[Acute Status], h.[Health Board Code],
hb.[Health Board], hb.[Population]
FROM wards w
LEFT OUTER JOIN hospitals h
ON w.[Hospital Code] = h.[Hospital Code]
LEFT OUTER JOIN hb 
ON h.[Health Board Code] = hb.[Health Board Code];'''

# Executing the query
cursor.execute(sql_query)

# Get column names
headers = [i[0] for i in cursor.description]

# Fetch rows from the result table and assign column names
health_data = pd.DataFrame(cursor.fetchall())
health_data.columns = headers
conn.close()
health_data
# Out:
#             Ward Name Ward Code Hospital Code                Hospital Name  \
# 0               ICU A  UHC:ICUA        UHC123  University Hospital Capital
# 1               ICU B  UHC:ICUB        UHC123  University Hospital Capital
# 2                 A&E    UHC:AE        UHC123  University Hospital Capital
# 3              Ward 1     UHC:1        UHC123  University Hospital Capital
# 4              Ward 2     UHC:2        UHC123  University Hospital Capital
# 5           Maternity   UHC:MAT        UHC123  University Hospital Capital
# 6          Palliative   DTH:PAL        DTH111            Downtown Hospital
# 7              Ward 1     DTH:1        DTH111            Downtown Hospital
# 8              Ward 2     DTH:2        DTH111            Downtown Hospital
# 9         Paediatrics   SSG:PAE        SSG001            Southside General
# 10           Oncology   SSG:ONC        SSG001            Southside General
# 11                A&E    SSG:AE        SSG001            Southside General
# 12         Geriatrics   FTG:GER        FTG221             Fir Tree General
# 13             Ward 1     FTG:1        FTG221             Fir Tree General
# 14         Psychiatic   FTG:PSY        FTG221             Fir Tree General
# 15  Internal Medicine  ORI:INTM        ORI010        Oaken Ridge Infirmary
# 16   General Medicine  ORI:GENM        ORI010        Oaken Ridge Infirmary
# 17             Ward 1     ORI:1        ORI010        Oaken Ridge Infirmary
# 18             Ward 1     NHHL1        NHH131            New Hope Hospital
# 19        Respiratory   NHH:RES        NHH131            New Hope Hospital
# 20              ICU A  BGH:ICUA        BDH101         Bright Dawn Hospital
# 21              ICU B  BGH:ICUB        BDH101         Bright Dawn Hospital
# 22             Ward 1     BGH:1        BDH101         Bright Dawn Hospital
# 23                A&E    TVI:AE        TVI854         The Valley Infirmary
#
#    Acute Status Health Board Code    Health Board  Population
# 0         Acute               CPR  Capital Region       20000
# 1         Acute               CPR  Capital Region       20000
# 2         Acute               CPR  Capital Region       20000
# 3         Acute               CPR  Capital Region       20000
# 4         Acute               CPR  Capital Region       20000
# 5         Acute               CPR  Capital Region       20000
# 6     Non Acute               CPR  Capital Region       20000
# 7     Non Acute               CPR  Capital Region       20000
# 8     Non Acute               CPR  Capital Region       20000
# 9         Acute               CPR  Capital Region       20000
# 10        Acute               CPR  Capital Region       20000
# 11        Acute               CPR  Capital Region       20000
# 12    Non Acute               FRH  Forest Heights       11000
# 13    Non Acute               FRH  Forest Heights       11000
# 14    Non Acute               FRH  Forest Heights       11000
# 15        Acute               FRH  Forest Heights       11000
# 16        Acute               FRH  Forest Heights       11000
# 17        Acute               FRH  Forest Heights       11000
# 18        Acute               MPK      Middlepark        8000
# 19        Acute               MPK      Middlepark        8000
# 20        Acute               MPK      Middlepark        8000
# 21        Acute               MPK      Middlepark        8000
# 22        Acute               MPK      Middlepark        8000
# 23        Acute               DLE        The Dale        1500

# %%
# Connect to patient database
conn = db.connect('PatientData.db')

# Create cursor object
cursor = conn.cursor()

# Query for LEFT JOIN
sql_query = '''SELECT p.[Patient ID], p.[Age], p.[Sex], p.[Unit Admission Date],
p.[Unit Discharge Date], p.[Specimen Date], p.[Organism], p.[Ward Code]
FROM patients p;'''

# Executing the query
cursor.execute(sql_query)

# Get column names
headers = [i[0] for i in cursor.description]

# Fetch rows from the result table and assign column names
patient_data = pd.DataFrame(cursor.fetchall())
patient_data.columns = headers
conn.close()
patient_data.head(5)
# Out:
#    Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 0      154907   49    Male          2019-10-05          2019-11-04
# 1      380679   28  Female          2019-05-20          2019-06-10
# 2      191421   37  Female          2019-06-30          2019-07-24
# 3      906309   51    Male          2021-08-17          2021-09-12
# 4      527023   84    Male          2020-12-12          2021-01-09
#
#   Specimen Date               Organism Ward Code
# 0    2021-05-31  Staphylococcus aureus   DTH:PAL
# 1    2022-07-09  Enterococcus faecalis   FTG:PSY
# 2    2023-09-04  Enterococcus faecalis   SSG:ONC
# 3    2021-08-19       Escherichia coli  UHC:ICUA
# 4    2019-08-03  Klebsiella pneumoniae     DTH:1

# %% [markdown]
# ## Identify patients whose positive sample occured on day 3 or later of a stay in healthcare (to account for incubation time of organism). Day of admission is taken as day 1 of healthcare stay

# %%
patient_data ["Specimen Date"]= pd.to_datetime(patient_data['Specimen Date'])
patient_data["Unit Admission Date"] = pd.to_datetime(patient_data["Unit Admission Date"])
patient_data["Unit Discharge Date"] = pd.to_datetime(patient_data["Unit Discharge Date"])
patient_data['HAI'] = np.where((patient_data['Specimen Date'] >= patient_data['Unit Admission Date']+timedelta(days=2)) & (patient_data['Specimen Date'] <= patient_data['Unit Discharge Date']),1,0)
patient_data['Days To Infection'] = (patient_data['Specimen Date'] - patient_data['Unit Admission Date']).dt.days
patient_data.head(10)
# Out:
#    Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 0      154907   49    Male          2019-10-05          2019-11-04
# 1      380679   28  Female          2019-05-20          2019-06-10
# 2      191421   37  Female          2019-06-30          2019-07-24
# 3      906309   51    Male          2021-08-17          2021-09-12
# 4      527023   84    Male          2020-12-12          2021-01-09
# 5      379501   90  Female          2023-06-16          2023-06-25
# 6      212931   50    Male          2022-07-15          2022-07-28
# 7      979234   28  Female          2021-05-01          2021-05-03
# 8      140007   19  Female          2021-02-28          2021-03-16
# 9      497540   71  Female          2019-07-03          2019-07-24
#
#   Specimen Date                Organism Ward Code  HAI  Days To Infection
# 0    2021-05-31   Staphylococcus aureus   DTH:PAL    0                604
# 1    2022-07-09   Enterococcus faecalis   FTG:PSY    0               1146
# 2    2023-09-04   Enterococcus faecalis   SSG:ONC    0               1527
# 3    2021-08-19        Escherichia coli  UHC:ICUA    1                  2
# 4    2019-08-03   Klebsiella pneumoniae     DTH:1    0               -497
# 5    2023-06-19   Enterococcus faecalis   SSG:PAE    1                  3
# 6    2022-07-22   Staphylococcus aureus  ORI:INTM    1                  7
# 7    2023-03-27  Pseudomonas aeruginosa  BGH:ICUB    0                695
# 8    2019-02-28   Enterococcus faecalis   SSG:PAE    0               -731
# 9    2020-10-13        Escherichia coli   SSG:ONC    0                468

# %% [markdown]
# ### Create Age Groups and Length Of Stay for patient data.

# %%
# List of conditions
conditions = [
      (patient_data["Age"] >= 0) & (patient_data["Age"] <= 16)
    , (patient_data["Age"] > 16) & (patient_data["Age"] <= 30)
    , (patient_data["Age"] > 30) & (patient_data["Age"] <= 50)
    , (patient_data["Age"] > 50) & (patient_data["Age"] <= 65)
    , (patient_data["Age"] > 65)
]
# List of values to return
choices  = [
      "0-16"
    , "17-30"
    , "31-50"
    , "51-65"
    , "65+"
]
# create a new column in the DF based on the conditions
patient_data["Age Group"] = np.select(conditions, choices, "ERROR")
patient_data['Length Of Stay'] = (patient_data['Unit Discharge Date'] - patient_data['Unit Admission Date']).dt.days+1
patient_data.head(5)
# Out:
#    Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 0      154907   49    Male          2019-10-05          2019-11-04
# 1      380679   28  Female          2019-05-20          2019-06-10
# 2      191421   37  Female          2019-06-30          2019-07-24
# 3      906309   51    Male          2021-08-17          2021-09-12
# 4      527023   84    Male          2020-12-12          2021-01-09
#
#   Specimen Date               Organism Ward Code  HAI  Days To Infection  \
# 0    2021-05-31  Staphylococcus aureus   DTH:PAL    0                604
# 1    2022-07-09  Enterococcus faecalis   FTG:PSY    0               1146
# 2    2023-09-04  Enterococcus faecalis   SSG:ONC    0               1527
# 3    2021-08-19       Escherichia coli  UHC:ICUA    1                  2
# 4    2019-08-03  Klebsiella pneumoniae     DTH:1    0               -497
#
#   Age Group  Length Of Stay
# 0     31-50              31
# 1     17-30              22
# 2     31-50              25
# 3     51-65              27
# 4       65+              29

# %% [markdown]
# ### Merge the datasets together describing the healthcare setting and patient information based on Ward Code

# %%
df = pd.merge(patient_data,health_data,on='Ward Code',how='left')
df['Month_Year'] = df['Specimen Date'].dt.to_period('M')
df.head(5)
# Out:
#    Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 0      154907   49    Male          2019-10-05          2019-11-04
# 1      380679   28  Female          2019-05-20          2019-06-10
# 2      191421   37  Female          2019-06-30          2019-07-24
# 3      906309   51    Male          2021-08-17          2021-09-12
# 4      527023   84    Male          2020-12-12          2021-01-09
#
#   Specimen Date               Organism Ward Code  HAI  Days To Infection  \
# 0    2021-05-31  Staphylococcus aureus   DTH:PAL    0                604
# 1    2022-07-09  Enterococcus faecalis   FTG:PSY    0               1146
# 2    2023-09-04  Enterococcus faecalis   SSG:ONC    0               1527
# 3    2021-08-19       Escherichia coli  UHC:ICUA    1                  2
# 4    2019-08-03  Klebsiella pneumoniae     DTH:1    0               -497
#
#   Age Group  Length Of Stay   Ward Name Hospital Code  \
# 0     31-50              31  Palliative        DTH111
# 1     17-30              22  Psychiatic        FTG221
# 2     31-50              25    Oncology        SSG001
# 3     51-65              27       ICU A        UHC123
# 4       65+              29      Ward 1        DTH111
#
#                  Hospital Name Acute Status Health Board Code    Health Board  \
# 0            Downtown Hospital    Non Acute               CPR  Capital Region
# 1             Fir Tree General    Non Acute               FRH  Forest Heights
# 2            Southside General        Acute               CPR  Capital Region
# 3  University Hospital Capital        Acute               CPR  Capital Region
# 4            Downtown Hospital    Non Acute               CPR  Capital Region
#
#    Population Month_Year
# 0       20000    2021-05
# 1       11000    2022-07
# 2       20000    2023-09
# 3       20000    2021-08
# 4       20000    2019-08

# %% [markdown]
# ### For each patient, find the day of admission, day of dischargeand fill in all the dates in between.

# %%
# Function to get all dates between admission and discharge date
def get_dates(row):
    return pd.date_range(start=row['Unit Admission Date'], end=row['Unit Discharge Date']).tolist()

# Create a list to store the results
all_dates = []

# Iterate through each row of the original DataFrame and append dates to the list
for _, row in df.iterrows():
    dates_between = get_dates(row)
    all_dates.extend(dates_between)

# Create a new DataFrame from the list of dates
bed_days_df = pd.DataFrame({'All_Dates': all_dates})

bed_days_df.head(40)
# Out:
#     All_Dates
# 0  2019-10-05
# 1  2019-10-06
# 2  2019-10-07
# 3  2019-10-08
# 4  2019-10-09
# 5  2019-10-10
# 6  2019-10-11
# 7  2019-10-12
# 8  2019-10-13
# 9  2019-10-14
# 10 2019-10-15
# 11 2019-10-16
# 12 2019-10-17
# 13 2019-10-18
# 14 2019-10-19
# 15 2019-10-20
# 16 2019-10-21
# 17 2019-10-22
# 18 2019-10-23
# 19 2019-10-24
# 20 2019-10-25
# 21 2019-10-26
# 22 2019-10-27
# 23 2019-10-28
# 24 2019-10-29
# 25 2019-10-30
# 26 2019-10-31
# 27 2019-11-01
# 28 2019-11-02
# 29 2019-11-03
# 30 2019-11-04
# 31 2019-05-20
# 32 2019-05-21
# 33 2019-05-22
# 34 2019-05-23
# 35 2019-05-24
# 36 2019-05-25
# 37 2019-05-26
# 38 2019-05-27
# 39 2019-05-28

# %% [markdown]
# ### Create a new dataframe that we can use to group demographic data and count how many bed days were occupied by each demographic each month. First, multrepeat each patient's demographic data the same number as days spent in healthcare (ie a patient in a ward for 3 days will have 3 rows of data)

# %%
# Function to repeat IDs and Ages based on the value in 'Length of Stay' column
def repeat_ids_and_ages(row):
    return pd.DataFrame({'Sex': [row['Sex']] * row['Length Of Stay'], 
                         'Age Group': [row['Age Group']] * row['Length Of Stay'], 
                         'Ward Code': [row['Ward Code']] * row['Length Of Stay'],
                         'Health Board': [row['Health Board']] * row['Length Of Stay']})

# Create a list to store the repeated IDs and Ages
all_data = []

# Iterate through each row of the original DataFrame and append repeated IDs and Ages to the list
for _, row in df.iterrows():
    repeated_data = repeat_ids_and_ages(row)
    all_data.append(repeated_data)

# Concatenate all the repeated data DataFrames into a single DataFrame
demographics_df = pd.concat(all_data, ignore_index=True)

demographics_df.head(10)
# Out:
#     Sex Age Group Ward Code    Health Board
# 0  Male     31-50   DTH:PAL  Capital Region
# 1  Male     31-50   DTH:PAL  Capital Region
# 2  Male     31-50   DTH:PAL  Capital Region
# 3  Male     31-50   DTH:PAL  Capital Region
# 4  Male     31-50   DTH:PAL  Capital Region
# 5  Male     31-50   DTH:PAL  Capital Region
# 6  Male     31-50   DTH:PAL  Capital Region
# 7  Male     31-50   DTH:PAL  Capital Region
# 8  Male     31-50   DTH:PAL  Capital Region
# 9  Male     31-50   DTH:PAL  Capital Region

# %% [markdown]
# ### Attach the column of each date that a patient was in healthcare

# %%
bed_days_df = pd.concat([bed_days_df.reset_index(drop=True), demographics_df], axis=1)
bed_days_df.head(5)
# Out:
#    All_Dates   Sex Age Group Ward Code    Health Board
# 0 2019-10-05  Male     31-50   DTH:PAL  Capital Region
# 1 2019-10-06  Male     31-50   DTH:PAL  Capital Region
# 2 2019-10-07  Male     31-50   DTH:PAL  Capital Region
# 3 2019-10-08  Male     31-50   DTH:PAL  Capital Region
# 4 2019-10-09  Male     31-50   DTH:PAL  Capital Region

# %% [markdown]
# ### Replace the full dates with a 'Month_Year' combo. This is the date stratification that will be used in the resuting dashboard.

# %%
bed_days_df['Month_Year'] = bed_days_df['All_Dates'].dt.to_period('M')
bed_days_df = bed_days_df.drop('All_Dates', axis=1)
bed_days_df = bed_days_df[['Month_Year', 'Sex', 'Age Group', 'Ward Code', 'Health Board']]
bed_days_df.head(40)
# Out:
#    Month_Year     Sex Age Group Ward Code    Health Board
# 0     2019-10    Male     31-50   DTH:PAL  Capital Region
# 1     2019-10    Male     31-50   DTH:PAL  Capital Region
# 2     2019-10    Male     31-50   DTH:PAL  Capital Region
# 3     2019-10    Male     31-50   DTH:PAL  Capital Region
# 4     2019-10    Male     31-50   DTH:PAL  Capital Region
# 5     2019-10    Male     31-50   DTH:PAL  Capital Region
# 6     2019-10    Male     31-50   DTH:PAL  Capital Region
# 7     2019-10    Male     31-50   DTH:PAL  Capital Region
# 8     2019-10    Male     31-50   DTH:PAL  Capital Region
# 9     2019-10    Male     31-50   DTH:PAL  Capital Region
# 10    2019-10    Male     31-50   DTH:PAL  Capital Region
# 11    2019-10    Male     31-50   DTH:PAL  Capital Region
# 12    2019-10    Male     31-50   DTH:PAL  Capital Region
# 13    2019-10    Male     31-50   DTH:PAL  Capital Region
# 14    2019-10    Male     31-50   DTH:PAL  Capital Region
# 15    2019-10    Male     31-50   DTH:PAL  Capital Region
# 16    2019-10    Male     31-50   DTH:PAL  Capital Region
# 17    2019-10    Male     31-50   DTH:PAL  Capital Region
# 18    2019-10    Male     31-50   DTH:PAL  Capital Region
# 19    2019-10    Male     31-50   DTH:PAL  Capital Region
# 20    2019-10    Male     31-50   DTH:PAL  Capital Region
# 21    2019-10    Male     31-50   DTH:PAL  Capital Region
# 22    2019-10    Male     31-50   DTH:PAL  Capital Region
# 23    2019-10    Male     31-50   DTH:PAL  Capital Region
# 24    2019-10    Male     31-50   DTH:PAL  Capital Region
# 25    2019-10    Male     31-50   DTH:PAL  Capital Region
# 26    2019-10    Male     31-50   DTH:PAL  Capital Region
# 27    2019-11    Male     31-50   DTH:PAL  Capital Region
# 28    2019-11    Male     31-50   DTH:PAL  Capital Region
# 29    2019-11    Male     31-50   DTH:PAL  Capital Region
# 30    2019-11    Male     31-50   DTH:PAL  Capital Region
# 31    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 32    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 33    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 34    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 35    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 36    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 37    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 38    2019-05  Female     17-30   FTG:PSY  Forest Heights
# 39    2019-05  Female     17-30   FTG:PSY  Forest Heights

# %% [markdown]
# ### Remove dataframe no longer needed

# %%
del(demographics_df)

# %% [markdown]
# ### Group by all needed combinations and count number of occurances

# %%
bed_days_df['TotalPatientDays'] = bed_days_df.groupby('Month_Year')['Month_Year'].transform('count')
bed_days_df['TotalPatientDaysBySex'] = bed_days_df.groupby(['Month_Year', 'Sex'])['Month_Year'].transform('count')
bed_days_df['TotalPatientDaysByAge'] = bed_days_df.groupby(['Month_Year', 'Age Group'])['Month_Year'].transform('count')
bed_days_df['BoardPatientDays'] = bed_days_df.groupby(['Month_Year', 'Health Board'])['Month_Year'].transform('count')
bed_days_df['BoardPatientDaysBySex'] = bed_days_df.groupby(['Month_Year', 'Health Board', 'Sex'])['Month_Year'].transform('count')
bed_days_df['BoardPatientDaysByAge'] = bed_days_df.groupby(['Month_Year', 'Health Board', 'Age Group'])['Month_Year'].transform('count')
bed_days_df['UnitPatientDays'] = bed_days_df.groupby(['Month_Year', 'Ward Code'])['Month_Year'].transform('count')
bed_days_df['UnitPatientDaysBySex'] = bed_days_df.groupby(['Month_Year', 'Ward Code', 'Sex'])['Month_Year'].transform('count')
bed_days_df['UnitPatientDaysByAge'] = bed_days_df.groupby(['Month_Year', 'Ward Code', 'Age Group'])['Month_Year'].transform('count')
bed_days_df = bed_days_df.drop_duplicates()
bed_days_df
# Out:
#       Month_Year     Sex Age Group Ward Code    Health Board  \
# 0        2019-10    Male     31-50   DTH:PAL  Capital Region
# 27       2019-11    Male     31-50   DTH:PAL  Capital Region
# 31       2019-05  Female     17-30   FTG:PSY  Forest Heights
# 43       2019-06  Female     17-30   FTG:PSY  Forest Heights
# 53       2019-06  Female     31-50   SSG:ONC  Capital Region
# ...          ...     ...       ...       ...             ...
# 79977    2022-01  Female     51-65     UHC:1  Capital Region
# 80059    2020-06  Female     51-65  ORI:GENM  Forest Heights
# 80102    2021-09  Female       65+     ORI:1  Forest Heights
# 80117    2023-08    Male       65+     DTH:2  Capital Region
# 80154    2019-05    Male       65+  ORI:GENM  Forest Heights
#
#        TotalPatientDays  TotalPatientDaysBySex  TotalPatientDaysByAge  \
# 0                  1362                    667                    415
# 27                 1276                    584                    324
# 31                 1402                    613                    313
# 43                 1223                    583                    206
# 53                 1223                    583                    335
# ...                 ...                    ...                    ...
# 79977              1647                    903                    264
# 80059              1452                    731                    203
# 80102              1303                    610                    498
# 80117               952                    490                    367
# 80154              1402                    789                    562
#
#        BoardPatientDays  BoardPatientDaysBySex  BoardPatientDaysByAge  \
# 0                   683                    335                    276
# 27                  476                    206                     81
# 31                  486                    233                     83
# 43                  348                    162                     52
# 53                  540                    295                    191
# ...                 ...                    ...                    ...
# 79977               929                    480                    180
# 80059               393                    245                     91
# 80102               281                    146                     70
# 80117               434                    224                    196
# 80154               486                    253                    224
#
#        UnitPatientDays  UnitPatientDaysBySex  UnitPatientDaysByAge
# 0                   77                    57                    27
# 27                  60                    48                    17
# 31                  79                    30                    12
# 43                  75                    19                    10
# 53                  27                    24                    24
# ...                ...                   ...                   ...
# 79977               91                    74                    24
# 80059               66                    26                    51
# 80102               69                    56                    13
# 80117               46                    11                    35
# 80154               22                    14                    14
#
# [5423 rows x 14 columns]

# %% [markdown]
# ### Merge results of counting by groups with patient data

# %%
final_df = pd.merge(df,bed_days_df,on=['Month_Year', 'Sex', 'Age Group', 'Ward Code', 'Health Board'],how='left')
final_df.head(5)
# Out:
#    Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 0      154907   49    Male          2019-10-05          2019-11-04
# 1      380679   28  Female          2019-05-20          2019-06-10
# 2      191421   37  Female          2019-06-30          2019-07-24
# 3      906309   51    Male          2021-08-17          2021-09-12
# 4      527023   84    Male          2020-12-12          2021-01-09
#
#   Specimen Date               Organism Ward Code  HAI  Days To Infection  ...  \
# 0    2021-05-31  Staphylococcus aureus   DTH:PAL    0                604  ...
# 1    2022-07-09  Enterococcus faecalis   FTG:PSY    0               1146  ...
# 2    2023-09-04  Enterococcus faecalis   SSG:ONC    0               1527  ...
# 3    2021-08-19       Escherichia coli  UHC:ICUA    1                  2  ...
# 4    2019-08-03  Klebsiella pneumoniae     DTH:1    0               -497  ...
#
#   Month_Year  TotalPatientDays TotalPatientDaysBySex TotalPatientDaysByAge  \
# 0    2021-05            1270.0                 716.0                 310.0
# 1    2022-07            1316.0                 681.0                 208.0
# 2    2023-09               NaN                   NaN                   NaN
# 3    2021-08            1422.0                 728.0                 229.0
# 4    2019-08            1188.0                 554.0                 478.0
#
#   BoardPatientDays BoardPatientDaysBySex BoardPatientDaysByAge  \
# 0            683.0                 419.0                 183.0
# 1            375.0                 259.0                  95.0
# 2              NaN                   NaN                   NaN
# 3            676.0                 385.0                 118.0
# 4            603.0                 258.0                 244.0
#
#   UnitPatientDays  UnitPatientDaysBySex UnitPatientDaysByAge
# 0            32.0                  24.0                 14.0
# 1            11.0                  11.0                  8.0
# 2             NaN                   NaN                  NaN
# 3            26.0                  22.0                 15.0
# 4            32.0                   8.0                 32.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Final step is to create a dummy entry for all combinations of date, sex, ward, hospital etc so that when plotting in Tableau, there are no missing values

# %%
unique_units = sorted(final_df['Ward Code'].unique())
unique_dates = sorted(final_df['Month_Year'].unique())
unique_ages = sorted(final_df['Age Group'].unique())
unique_sexes = sorted(final_df['Sex'].unique())
all_combinations = list(product(unique_units, unique_dates, unique_ages, unique_sexes))
all_combinations_df = pd.DataFrame(all_combinations)
all_combinations_df = all_combinations_df.rename(columns={0 : "Ward Code", 1: "Month_Year", 2: "Age Group", 3: "Sex"})
all_combinations_df = pd.merge(all_combinations_df, health_data, on='Ward Code', how='left')
all_combinations_df.head(5)
# Out:
#   Ward Code Month_Year Age Group     Sex Ward Name Hospital Code  \
# 0     BGH:1    2019-01     17-30  Female    Ward 1        BDH101
# 1     BGH:1    2019-01     17-30    Male    Ward 1        BDH101
# 2     BGH:1    2019-01     31-50  Female    Ward 1        BDH101
# 3     BGH:1    2019-01     31-50    Male    Ward 1        BDH101
# 4     BGH:1    2019-01     51-65  Female    Ward 1        BDH101
#
#           Hospital Name Acute Status Health Board Code Health Board  \
# 0  Bright Dawn Hospital        Acute               MPK   Middlepark
# 1  Bright Dawn Hospital        Acute               MPK   Middlepark
# 2  Bright Dawn Hospital        Acute               MPK   Middlepark
# 3  Bright Dawn Hospital        Acute               MPK   Middlepark
# 4  Bright Dawn Hospital        Acute               MPK   Middlepark
#
#    Population
# 0        8000
# 1        8000
# 2        8000
# 3        8000
# 4        8000

# %%
padding_df = pd.DataFrame(columns=final_df.columns.tolist())
padding_df['Ward Code'] = all_combinations_df['Ward Code']
padding_df['Month_Year'] = all_combinations_df['Month_Year']
padding_df['Age Group'] = all_combinations_df['Age Group']
padding_df['Sex'] = all_combinations_df['Sex']
padding_df['Ward Name'] = all_combinations_df['Ward Name']
padding_df['Hospital Code'] = all_combinations_df['Hospital Code']
padding_df['Hospital Name'] = all_combinations_df['Hospital Name']
padding_df['Acute Status'] = all_combinations_df['Acute Status']
padding_df['Health Board Code'] = all_combinations_df['Health Board Code']
padding_df['Health Board'] = all_combinations_df['Health Board']
padding_df['HAI'] = 0
padding_df.head(10)
# Out:
#   Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 0        NaN  NaN  Female                 NaN                 NaN
# 1        NaN  NaN    Male                 NaN                 NaN
# 2        NaN  NaN  Female                 NaN                 NaN
# 3        NaN  NaN    Male                 NaN                 NaN
# 4        NaN  NaN  Female                 NaN                 NaN
# 5        NaN  NaN    Male                 NaN                 NaN
# 6        NaN  NaN  Female                 NaN                 NaN
# 7        NaN  NaN    Male                 NaN                 NaN
# 8        NaN  NaN  Female                 NaN                 NaN
# 9        NaN  NaN    Male                 NaN                 NaN
#
#   Specimen Date Organism Ward Code  HAI Days To Infection  ... Month_Year  \
# 0           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 1           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 2           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 3           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 4           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 5           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 6           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 7           NaN      NaN     BGH:1    0               NaN  ...    2019-01
# 8           NaN      NaN     BGH:1    0               NaN  ...    2019-02
# 9           NaN      NaN     BGH:1    0               NaN  ...    2019-02
#
#   TotalPatientDays TotalPatientDaysBySex TotalPatientDaysByAge  \
# 0              NaN                   NaN                   NaN
# 1              NaN                   NaN                   NaN
# 2              NaN                   NaN                   NaN
# 3              NaN                   NaN                   NaN
# 4              NaN                   NaN                   NaN
# 5              NaN                   NaN                   NaN
# 6              NaN                   NaN                   NaN
# 7              NaN                   NaN                   NaN
# 8              NaN                   NaN                   NaN
# 9              NaN                   NaN                   NaN
#
#   BoardPatientDays BoardPatientDaysBySex BoardPatientDaysByAge  \
# 0              NaN                   NaN                   NaN
# 1              NaN                   NaN                   NaN
# 2              NaN                   NaN                   NaN
# 3              NaN                   NaN                   NaN
# 4              NaN                   NaN                   NaN
# 5              NaN                   NaN                   NaN
# 6              NaN                   NaN                   NaN
# 7              NaN                   NaN                   NaN
# 8              NaN                   NaN                   NaN
# 9              NaN                   NaN                   NaN
#
#   UnitPatientDays UnitPatientDaysBySex UnitPatientDaysByAge
# 0             NaN                  NaN                  NaN
# 1             NaN                  NaN                  NaN
# 2             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 4             NaN                  NaN                  NaN
# 5             NaN                  NaN                  NaN
# 6             NaN                  NaN                  NaN
# 7             NaN                  NaN                  NaN
# 8             NaN                  NaN                  NaN
# 9             NaN                  NaN                  NaN
#
# [10 rows x 29 columns]

# %%
final_df = pd.concat([final_df, padding_df])

# %%
final_df.tail(5)
# Out:
#       Patient ID  Age     Sex Unit Admission Date Unit Discharge Date  \
# 10747        NaN  NaN    Male                 NaT                 NaT
# 10748        NaN  NaN  Female                 NaT                 NaT
# 10749        NaN  NaN    Male                 NaT                 NaT
# 10750        NaN  NaN  Female                 NaT                 NaT
# 10751        NaN  NaN    Male                 NaT                 NaT
#
#       Specimen Date Organism Ward Code  HAI Days To Infection  ...  \
# 10747           NaT      NaN   UHC:MAT    0               NaN  ...
# 10748           NaT      NaN   UHC:MAT    0               NaN  ...
# 10749           NaT      NaN   UHC:MAT    0               NaN  ...
# 10750           NaT      NaN   UHC:MAT    0               NaN  ...
# 10751           NaT      NaN   UHC:MAT    0               NaN  ...
#
#       TotalPatientDays TotalPatientDaysBySex TotalPatientDaysByAge  \
# 10747              NaN                   NaN                   NaN
# 10748              NaN                   NaN                   NaN
# 10749              NaN                   NaN                   NaN
# 10750              NaN                   NaN                   NaN
# 10751              NaN                   NaN                   NaN
#
#       BoardPatientDays BoardPatientDaysBySex BoardPatientDaysByAge  \
# 10747              NaN                   NaN                   NaN
# 10748              NaN                   NaN                   NaN
# 10749              NaN                   NaN                   NaN
# 10750              NaN                   NaN                   NaN
# 10751              NaN                   NaN                   NaN
#
#       UnitPatientDays UnitPatientDaysBySex UnitPatientDaysByAge  \
# 10747             NaN                  NaN                  NaN
# 10748             NaN                  NaN                  NaN
# 10749             NaN                  NaN                  NaN
# 10750             NaN                  NaN                  NaN
# 10751             NaN                  NaN                  NaN
#
#          Health Board
# 10747  Capital Region
# 10748  Capital Region
# 10749  Capital Region
# 10750  Capital Region
# 10751  Capital Region
#
# [5 rows x 31 columns]

# %%
final_df.to_csv('data.csv', index=False)
